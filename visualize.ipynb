# %%
import numpy as np
import os
import json
import glob
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
import sys

# %matplotlib inline
print(os.getcwd())
# Out:
# /Users/muhsinfatih/developer/algorithms/spatialtree

# %%
def bar_range(col, r):
    return np.arange(min(col), max(col) + r, r)

# %%
# %matplotlib notebook
# %matplotlib widget
points = json.load(open('points_annotated.json'))['points']
points = np.array(points)

print(points[:5])

xdata = points[:,0]
ydata = points[:,1]
zdata = points[:,2]
labels = points[:,3]

colors = "wwkbgrcmybgrcmybgrcmybgrcmy"

colors = [colors[int(labels[i])] for i in range(len(labels))]
fig = plt.figure(figsize=(15,13))
ax = plt.axes(projection='3d')
ax.scatter3D(xdata, ydata, zdata, c=colors, s=3)
# Out:
# ...
# [[-0.12 -0.32 -0.25  2.  ]
#  [-0.02 -0.1  -0.1   3.  ]
#  [-0.01 -0.1  -0.11  3.  ]
#  [-0.02 -0.11 -0.12  3.  ]
#  [-0.02 -0.07 -0.26  3.  ]]
# <img src="data:image/png;base64,..." width="1080">
